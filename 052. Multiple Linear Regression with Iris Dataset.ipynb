# %%
import pandas as pd

# %%
# Import the dataset in spreadsheet into the workspace (DataFrame)
adsdataset = pd.read_csv('D:/data/others/Advertising.csv')

# %%
adsdataset.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
# How to remove unneccessary column from a dataset
adsdataset = adsdataset[['TV', 'radio', 'newspaper', 'sales']]

# %%
adsdataset.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
# y = f(x1,x2,x3)

# y = f(x1)
x1 = adsdataset['TV']
x2 = adsdataset['radio']
x3 = adsdataset['newspaper']
y = adsdataset['sales']

# %%
# Matplotlib is used for plotting

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x1,y)

# %%
y_estimate = 7.033 + 0.048*x1

# %%
plt.scatter(x1, y, color='blue')
plt.plot(x1, y_estimate, color='red')
plt.show()

# %%
fig = plt.figure(figsize=(10,5))

plt.subplot(1,3,1)
plt.scatter(x1, y, color='green')

plt.subplot(1,3,2)
plt.scatter(x2, y, color='red')

plt.subplot(1,3,3)
plt.scatter(x3, y, color='blue')

plt.show()

# %%
# Use seaborn for data visualisation (Scatter matrix)
import seaborn as sb

# %%
sb.pairplot(adsdataset)

# %%
# use pandas.plotting for visualization
import pandas.plotting as pp

# %%
plot = pp.scatter_matrix(adsdataset)

# %%
# Now perform Linear Regression using Sklearn.linear_models
from sklearn.linear_model import LinearRegression

# %%
# This step is called preprocessing
x1 = x1.values.reshape(-1, 1)

# %%
#Create  a Linear Regression variable
linvar = LinearRegression()
linvar.fit(x1,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(linvar.coef_)
# Out:
# [0.04753664]

# %%
print(linvar.intercept_)
# Out:
# 7.032593549127693

# %%
adsdataset.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
7.033 + 0.048 * 230.1
# Out:
# 18.0778

# %%
#Perform Linear Regression Using statsmodel
import statsmodels.api as sm

x1 = sm.add_constant(x1)

linmod2 = sm.OLS(y, x1).fit()

# %%
linmod2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Sat, 17 Aug 2019   Prob (F-statistic):           1.47e-42
# Time:                        22:28:26   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.0326      0.458     15.360      0.000       6.130       7.935
# ...

# %%
plt.scatter(x1,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-2e9c785e9c38> in <module>()
# ----> 1 plt.scatter(x1,y)
#
# D:\Users\Hp\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3468                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3469                          linewidths=linewidths, verts=verts,
# -> 3470                          edgecolors=edgecolors, data=data, **kwargs)
#    3471     finally:
#    3472         ax._hold = washold
#
# D:\Users\Hp\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
# ...
